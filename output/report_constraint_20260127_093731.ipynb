# %% [markdown]
# # ⚠️ Constraint Violation Report
# **Generated on:** 2026-01-27 09:37:31

# %% [markdown]
# ## ⚙️ System Configuration
# Model: `lp_proxy` | Type: `LP` | Check: `constraint`

# %% [markdown]
# ### 🛡️ Safety Summary
# | Metric | Value |
# | :--- | :--- |
# | **Status** | ❌ VIOLATED |
# | **Worst Violation** | 0.024088 |
# #### 📏 Detailed Constraint Analysis
# | Row | Status | LHS Value | Limit (b) | Violation |
# | :--- | :--- | :--- | :--- | :--- |
# | 0 | ✅ | -4.4238 | 7.9844 | -12.4082 |
# | 1 | ✅ | 5.8141 | 9.4822 | -3.6681 |
# | 2 | ✅ | 0.4185 | 6.4474 | -6.0289 |
# | 3 | ✅ | 0.3360 | 7.9299 | -7.5939 |
# | 4 | ❌ | 0.0241 | 0.0000 | 0.0241 |

# %% [markdown]
# ## 📈 Analysis Visualization

# %%
import matplotlib.pyplot as plt
violations = [-12.408206939697266, -3.668056011199951, -6.028905868530273, -7.5938944816589355, 0.024088066071271896]
plt.figure(figsize=(10, 5))
plt.bar(range(len(violations)), violations, color=['red' if v > 1e-4 else 'green' for v in violations])
plt.axhline(y=0, color='black')
plt.title('Constraint Violations (Positive = Infeasible)')
plt.show()
